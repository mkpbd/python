# %%
set = {40,3,4,5,7,9,60}

s_iter = iter(set)

print(type(s_iter))

print(next(s_iter))
print(next(s_iter))
print(next(s_iter))
# Out:
# <class 'set_iterator'>
# 3
# 4
# 5

# %%
#iterator 

def interator (list):
     return iter(list)

data = interator([2,3,5,7,8,10,15, 16])



print(next(data))
print(next(data))
print(next(data))
print(next(data))
# Out:
# 2
# 3
# 5
# 7
