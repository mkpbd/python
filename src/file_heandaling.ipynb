# %% [markdown]
# File handling is an important part of any web application.
#
# Python has several functions for creating, reading, updating, and deleting files.
#
# File Handling
# The key function for working with files in Python is the open() function.
#
# The open() function takes two parameters; filename, and mode.
#
# There are four different methods (modes) for opening a file:
#
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
# "a" - Append - Opens a file for appending, creates the file if it does not exist
#
# "w" - Write - Opens a file for writing, creates the file if it does not exist
#
# "x" - Create - Creates the specified file, returns an error if the file exists
#
# In addition you can specify if the file should be handled as binary or text mode
#
# "t" - Text - Default value. Text mode
#
# "b" - Binary - Binary mode (e.g. images)

# %%
f = open('./file/demo.txt')

#The code above is the same as:
frt = open('./file/demo.txt', 'rt')
# Because "r" for read, and "t" for text are the default values, you do not need to specify them.
# Note : Make sure the file exists or else you will get an error 
# f.read()

frt.read()
frt.close()
# Out:
# 'hello bangladesh'

# %%
# Using the with statement
# with open('./file/demo.txt') as f :
    # print(f.read())

## file read line 

with open("./file/demo.txt") as fred:
    print(fred.readline())

#By looping through the lines of the file, you can read the whole file, line by line:

with open('./file/demo.txt') as floo:
    for x in floo:
        print(x)
# Out:
# hello bangladesh
#
# hello bangladesh
#
# make money form only
#
# we love bangladesh
#
# we make batter life
#
# we hove our eduction
#
# we want to make money

# %%
# file create 
# To write to an existing file, you must add a parameter to the open() function:

# "a" - Append - will append to the end of the file

# "w" - Write - will overwrite any existing content

with open('./file/test.txt', 'a') as fw:
    fw.write("Hello  Bangladesh \n")

#open and read the file after the appending 

with open ("./file/test.txt") as fr:
    print(fr.read())
# Out:
# Hello  Bangladesh

# %%
# Overwrite Existing Content
with open('./file/over-write.txt', 'w') as f:
    f.write('hello kamal you are over write ')

# open and read the file after the overwriting 
with open('./file/over-write.txt') as fr:
    print(fr.read())
# Out:
# hello kamal you are over write

# %% [markdown]
# Create a New File
# To create a new file in Python, use the open() method, with one of the following parameters:
#
# "x" - Create - will create a file, returns an error if the file exists
#
# "a" - Append - will create a file if the specified file does not exists
#
# "w" - Write - will create a file if the specified file does not exists

# %%
# create a new file 

f = open("./file/myfile.txt", "x")
# Note: If the file already exist, an error will be raised.
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[14], line 3
#       1 # create a new file
# ----> 3 f = open("./file/myfile.txt", "x")
#
# File c:\Users\mosto\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: './file/myfile.txt'

# %%
# file deleting 

import os 

os.remove('./file/myfile.txt')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[21], line 5
#       1 # file deleting
#       3 import os
# ----> 5 os.remove('./file/myfile.txt')
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: './file/myfile.txt'
