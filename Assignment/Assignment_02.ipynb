# %% [markdown]
# Watch the assignment instruction video carefully before starting.
# Create a Google Colaboratory (.ipynb) file in your Google Drive.
# Make Text Cell and give the following information:
#  Your registered email address (the one used for your Phitron account).
# Write all answers for all questions in a single file.
# For each question, create a Text cell with the question number and a Code cell with your solution.
# Print or display all required outputs clearly so that graders can verify results.
# Share the Colab file with “Anyone with the link” and permission set to “Viewer”.
# Submit only the Colab link.
# Note: Each Question is carrying 10 marks.

# %%
# You must run this code and use that data set for all the questions
import numpy as np
import pandas as pd

np.random.seed(42)

ids = np.arange(1, 11)
ages = np.random.randint(18, 60, 10)
salaries = np.random.randint(30000, 90000, 10)
departments = np.array(["HR", "IT", "Finance", "IT", "HR", "Sales", "Finance", "IT", "Sales", "HR"])

DF = pd.DataFrame({
"id": ids,
"age": ages,
"salary": salaries,
"dept": departments
})

DF.to_csv("employees.csv", index=False)
print("Sample Data Created and Saved as employees.csv")
# Out:
# Sample Data Created and Saved as employees.csv

# %% [markdown]
# # 1) NumPy — 5 Questions

# %% [markdown]
# Q1. Create NumPy arrays from the ages and salaries data generated above. Print both arrays and display their dtype, ndim, shape, and size.

# %%
import numpy as np
ages_array = np.array(ages)
salaries_array = np.array(salaries)

print("Ages Array :", ages_array)
print(f" dtype: {ages_array.dtype}")
print(f"ndim: {ages_array.ndim}")
print(f"shape: {ages_array.shape}")
print(f"size: {ages_array.size}")

print("Salary Array:" , salaries_array)
print(f"dtype: {salaries_array.dtype}")
print(f"ndim: {salaries_array.ndim}")
print(f"shape: {salaries_array.shape}")
print(f"size: {salaries_array.size}")
# Out:
# Ages Array : [56 46 32 25 38 56 36 40 28 28]
#  dtype: int32
# ndim: 1
# shape: (10,)
# size: 10
# Salary Array: [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# dtype: int32
# ndim: 1
# shape: (10,)
# size: 10

# %% [markdown]
# ## Q2. Using the salaries array, find and print the highest and lowest salary values. Also, calculate and print the average salary and age using NumPy functions.

# %%
import numpy as np
ages_array = np.array(ages)
salaries_array = np.array(salaries)
print(f"Highest Salary: {np.max(salaries_array):,}")
print(f"Lowest Salary: {np.min(salaries_array):,}")
print(f"Average Salary: {np.mean(salaries_array):,.2f}")
print(f"Average Age: {np.mean(ages_array):.2f} years")
# Out:
# Highest Salary: 89,735
# Lowest Salary: 30,769
# Average Salary: 57,446.90
# Average Age: 38.50 years

# %% [markdown]
# ## Q3. From the ages array, filter and print all ages greater than 30 using a boolean condition. Then count and print how many employees are older than 30.

# %%
import numpy as np
ages_array = np.array(ages)
salaries_array = np.array(salaries)

ages_gt_30 = ages_array[ages_array > 30]
print(f"Ages greater than 30: {ages_gt_30}")
print(f"Number of employees older than 30: {len(ages_gt_30)}")
# Out:
# Ages greater than 30: [56 46 32 38 56 36 40]
# Number of employees older than 30: 7

# %% [markdown]
# ## Q4. Create a new NumPy array that increases every employee’s age by 5 years (without modifying the original array). Print the new updated ages array.

# %%
import numpy as np
ages_array = np.array(ages)
salaries_array = np.array(salaries)
updated_ages = ages_array + 5
print(f"Original Ages: {ages_array}")
print(f"Updated Ages (+ 5 years): {updated_ages}")
# Out:
# Original Ages: [56 46 32 25 38 56 36 40 28 28]
# Updated Ages (+ 5 years): [61 51 37 30 43 61 41 45 33 33]

# %% [markdown]
# ## Q5. Using NumPy, calculate the total salary expense (sum of all salaries) and the difference between the maximum and minimum salary. Print both results.

# %%
import numpy as np
ages_array = np.array(ages)
salaries_array = np.array(salaries)
total_salary = np.sum(salaries_array)
salary_range = np.max(salaries_array) - np.min(salaries_array)
print(f"Total Salary Expense: {total_salary:,}")
print(f"Salary Range (Max - Min): {salary_range:,}")
# Out:
# Total Salary Expense: 574,469
# Salary Range (Max - Min): 58,966

# %% [markdown]
# ## Q6. Load the employees.csv file into a Pandas DataFrame. Display the first 5 rows, and check basic info using info() and summary statistics using describe().

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("employees.csv")
print("First 5 rows:")
print(df.head())
print("DataFrame Info:")
print(df.info())
print("Summary Statistics:")
print(df.describe())
# Out:
# First 5 rows:
#    id  age  salary     dept
# 0   1   56   77191       HR
# 1   2   46   74131       IT
# 2   3   32   46023  Finance
# 3   4   25   71090       IT
# 4   5   38   31685       HR
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10 non-null     int64
#  1   age     10 non-null     int64
#  2   salary  10 non-null     int64
#  3   dept    10 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 452.0+ bytes
# None
# Summary Statistics:
#              id       age        salary
# count  10.00000  10.00000     10.000000
# mean    5.50000  38.50000  57446.900000
# std     3.02765  11.16791  24357.262884
# min     1.00000  25.00000  30769.000000
# 25%     3.25000  29.00000  33152.500000
# 50%     5.50000  37.00000  58556.500000
# 75%     7.75000  44.50000  76426.000000
# max    10.00000  56.00000  89735.000000

# %% [markdown]
# ## Q7. Display only the id, age, and salary columns. Then show the last 3 rows using tail().

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("employees.csv")
print("Columns: id, age, salary")
print(df[['id', 'age', 'salary']])
print("Last 3 rows:")
print(df.tail(3))
# Out:
# Columns: id, age, salary
#    id  age  salary
# 0   1   56   77191
# 1   2   46   74131
# 2   3   32   46023
# 3   4   25   71090
# 4   5   38   31685
# 5   6   56   30769
# 6   7   36   89735
# 7   8   40   86101
# 8   9   28   32433
# 9  10   28   35311
# Last 3 rows:
#    id  age  salary   dept
# 7   8   40   86101     IT
# 8   9   28   32433  Sales
# 9  10   28   35311     HR

# %% [markdown]
# ## Q8. Filter the DataFrame to show only employees who work in the IT department. Print the result and show the total number of IT employees.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("employees.csv")
it_employees = df[df['dept'] == 'IT']
print(it_employees)
print(f"Total number of IT employees: {len(it_employees)}")
# Out:
#    id  age  salary dept
# 1   2   46   74131   IT
# 3   4   25   71090   IT
# 7   8   40   86101   IT
# Total number of IT employees: 3

# %% [markdown]
# ## Q9. Sort the DataFrame by salary in descending order and display the top 3 highest-paid employees along with their department and age.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("employees.csv")
top_3_earners = df.sort_values(by='salary', ascending=False).head(3)
print(top_3_earners[['id', 'age', 'salary', 'dept']])
# Out:
#    id  age  salary     dept
# 6   7   36   89735  Finance
# 7   8   40   86101       IT
# 0   1   56   77191       HR

# %% [markdown]
# ## Q10. Replace all salary values greater than 80000 with 80000 using loc. Then calculate and print the new average salary of all employees after replacement.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("employees.csv")

print(df['salary'].values)

df.loc[df['salary'] > 80000, 'salary'] = 80000
print("Salaries after capping at $80,000:")
print(df['salary'].values)

new_avg_salary = df['salary'].mean()
print(f"New Average Salary: {new_avg_salary:,.2f}")
# Out:
# [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# Salaries after capping at $80,000:
# [77191 74131 46023 71090 31685 30769 80000 80000 32433 35311]
# New Average Salary: 55,863.30
