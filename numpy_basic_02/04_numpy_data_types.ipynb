# %% [markdown]
# ## Data Types in python
#  _ string
#  _ integer
#  _ float
#  _ boolean
#  _ complex
# ## Data types in NumPy
# NumPy has some data types, and refer to data types with one character like  `i`  for integer  `u`  for unsigned integer etc
# Below is a list of all data types in NumPy and the characters used to represent them
#
# _ i -integer
# _ b -boolean
# _ u - unsigned integer
# _ f -float
# _ c -complex
# _ m -timedelta
# _ M -dateTime
# _ O -object
# _ S -string
# _ U -unicode string
# _ V -fixed chunk of memory for other type(void)

# %% [markdown]
# ## Checking the Data Type of an Array
# The NumPy array object has a property called `dtype` that returns the data type of the array

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5]);
print("Array:", arr)
print("data type", arr.dtype)
# Out:
# Array: [1 2 3 4 5]
# data type int64

# %%
## string type 
arr2 = np.array(['apple', 'banana', 'cherry']);
print("Array2:", arr2)
print("data type", arr2.dtype)
# Out:
# Array2: ['apple' 'banana' 'cherry']
# data type <U6

# %% [markdown]
# ## Creating Arrays With a Defined Data Types
# We use the `array()` function to crate arrays this function take an optional argument `dtype` that allows us to  defined the expected data type of the array elements

# %%
## create a array with data type string 
arr3 = np.array([1, 2, 3, 4], dtype='S');
print("Array3:", arr3)
print("data type", arr3.dtype)
# Out:
# Array3: [b'1' b'2' b'3' b'4']
# data type |S1

# %% [markdown]
# ## For  i, u, f, S and U we can define size as well

# %%
import numpy as np
## For  i, u, f, S and U we can define size as well
arr4 = np.array([1, 2, 3, 4], dtype='i4');
print("Array4:", arr4)
print("data type", arr4.dtype)
arr5 = np.array([1, 2, 3, 4], dtype='f8');
print("Array5:", arr5)     
print("data type", arr5.dtype)
# Out:
# Array4: [1 2 3 4]
# data type int32
# Array5: [1. 2. 3. 4.]
# data type float64

# %% [markdown]
# ## Converting Data type on Existing Arrays
# The best way to change the data type of an existing array is to make a copy  of the array with the  `astype()` method
# the `astype()` function creates a copy of the array and allows you to specify the data as a parameter
# the data type can be specified using a string like  'f' for float 'i' integer etc. or you can use the data type directly like float for float and int for integer

# %%
import numpy as np
## For  i, u, f, S and U we can define size as well
arr4 = np.array([1, 2, 3, 4], dtype='i4');
print("Array4:", arr4)
print("data type", arr4.dtype)
arr5 = np.array([1, 2, 3, 4], dtype='f8');
print("Array5:", arr5)
print("data type", arr5.dtype)
## Converting Data type on Existing Arrays
# The best way to change the data type of an existing array is to make a copy  of the array with the  `astype()` method   
# the `astype()` function creates a copy of the array and allows you to specify the data as a parameter
# the data type can be specified using a string like  'f' for float 'i' integer etc. or you can use the data type directly like float for float and int for integer

arr6 = np.array([1, 2, 3, 4, 5]);
print("Array6:", arr6)
print("data type", arr6.dtype)
arr7 = arr6.astype('f');
print("Array7:", arr7)
print("data type", arr7.dtype)
arr8 = arr6.astype(float);
print("Array8:", arr8)
print("data type", arr8.dtype)
# Out:
# Array4: [1 2 3 4]
# data type int32
# Array5: [1. 2. 3. 4.]
# data type float64
# Array6: [1 2 3 4 5]
# data type int64
# Array7: [1. 2. 3. 4. 5.]
# data type float32
# Array8: [1. 2. 3. 4. 5.]
# data type float64
