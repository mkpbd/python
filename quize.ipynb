# %%
def add (a, b = 2):
    return a +b
add(3)

get_filter= list(filter(lambda x: x%2==0, [1,2,3,4]))

print(get_filter)
# Out:
# [2, 4]

# %%
# G. Max and MIN

n = int(input())

a = input().strip()
a_number = list(map(int, a.split()))

min_value = (lambda x : sorted(x)[0])(a_number)
max_value = (lambda y: sorted(y)[-1])(a_number)


print(f"{min_value} {max_value}")






print(min_value)
print(a_number)
# Out:
# 1 95
# 1
# [10, 13, 95, 1, 3]

# %%
from functools import reduce
n = float(input())

a = input().strip()

array_list = list(map(float, a.split()))

avg =  reduce(lambda x, y : (x + y ), array_list)

print(f"{avg/n:.7f}")
print(array_list)
print(n)
# Out:
# 2.6666667
# [1.0, 2.0, 5.0]
# 3.0

# %%
n = int(input())

a_array = list(map(int , input().strip().split()))
b_array = list(map(int , input().strip().split()))

def  newArray(a, b):
   return  b + a

c_array = newArray(a_array, b_array)

for i in c_array:
   print(i , end=" ")
# Out:
# 3 4 1 2
