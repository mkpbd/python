# %%
# Dictonary 
#empty 
dic = {}

print(type(dic))

dic1 = {'name': 'kamal', 'age':20, 'address': 'Dhaka', 'number':[3,4,5,6,7]}
print(type(dic1), dic1)
# Out:
# <class 'dict'>
# <class 'dict'> {'name': 'kamal', 'age': 20, 'address': 'Dhaka', 'number': [3, 4, 5, 6, 7]}

# %%
## Accessing value of dictonary 

print(dic1['name'])
print(dic1.get('age'))

# update element
dic1['name'] = 'jamal'

print(dic1)
# Out:
# kamal
# 20
# {'name': 'jamal', 'age': 20, 'address': 'Dhaka', 'number': [3, 4, 5, 6, 7]}
