# %%
# set  is a unique values 
set_a = {2,3,4,5,6}

print(set_a)
print(type(set_a))

C = {}
print(type(C))

D = set();
print(type(D))
# Out:
# {2, 3, 4, 5, 6}
# <class 'set'>
# <class 'dict'>
# <class 'set'>

# %%
# access element in Set 
S ={1,2,3,4,5,6,7,8,9,9,5}

if 5 in S:
    print("this element in set")
else:
    print("this Element is not in Set")

sum = 0;

for element in S:
    sum += element

print(sum)

print(S)
# Out:
# this element in set
# 45
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
#set 
ss = {30, 10, 0, 20}
ss.add(3)

print(ss)
# Out:
# {0, 3, 10, 20, 30}

# %%
# get keys and values 
dic = {'a': 1, 'b': 2}

key = dic.keys()
print(key)
# Out:
# dict_keys(['a', 'b'])
