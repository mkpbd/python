# %% [markdown]
# # Python Indentation
# Indentation refers to the spaces at the beginning of a code line.
#
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
#
# Python uses indentation to indicate a block of code.

# %%
if 5 > 2:
    print("hello this is indentation")
# Out:
# hello this is indentension

# %%
#Python will give you an error if you skip the indentation:
if 5 > 2:
print("hello this will cause an error")  # This line will cause an IndentationError
# Out:
#   Cell In[2], line 3
#     print("hello this will cause an error")  # This line will cause an IndentationError
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# The number of spaces is up to you as a programmer, the most common use is four, but it has to be at least one.
if 5 > 2:
 print("Five is greater than one!") 
if 5 > 2:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %%
# You have to use the same number of spaces in the same block of code, otherwise Python will give you an error:
if 5 > 2:
 print("Five is greater than two!")
        print("Five is greater than two!")
# Out:
#   Cell In[4], line 4
#     print("Five is greater than two!")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # Comments
# Python has commenting capability for the purpose of in-code documentation.
#
# Comments start with a #, and Python will render the rest of the line as a comment:

# %%
#This is a comment.
print("Hello, World!")

# %% [markdown]
# # Statements
# A computer program is a list of "instructions" to be "executed" by a computer.
#
# In a programming language, these programming instructions are called statements.
#
# The following statement prints the text "Python is fun!" to the screen:

# %%
print("Python is fun!")

# %% [markdown]
# In Python, a statement usually ends when the line ends. You do not need to use a semicolon (;)
# like in many other programming languages (for example, Java or C).
#
# # Many Statements
# Most Python programs contain many statements.
#
# The statements are executed one by one, in the same order as they are written:

# %%
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %% [markdown]
# From the example above, we have three statements:
#
# print("Hello World!")
# print("Have a good day.")
# print("Learning Python is fun!")
#
# **The first statement is executed first (print "Hello World!")**.
#
# **Then the second statement is executed (print "Have a good day")**.
#
# **And at last, the third statement is executed (print "Learning Python is fun!").**
#
# Semicolons (Optional, Rarely Used)
# Semicolons are optional in Python. You can write multiple statements on one line by separating them with ; but this is rarely used because it makes it hard to read:
#
# **Best practice: Put each statement on its own line so your code is easy to understand.**

# %%
print("Hello"); print("How are you?"); print("Bye bye!")

## Best practice: Put each statement on its own line so your code is easy to understand.
# Out:
# Hello
# How are you?
# Bye bye!

# %% [markdown]
# # Python Output / Print
#
# we can use the `print()` function to display text or output values

# %%
print("Hello Bangladesh!")

# %% [markdown]
# You can use the print() function as many times as you want. Each call prints text on a new line by default:

# %%
print("Hello World!")
print("I am learning Python.")
print("It is awesome!")
# Out:
# Hello World!
# I am learning Python.
# It is awesome!

# %% [markdown]
# Double Quotes
# Text in Python must be inside quotes. You can use either " double quotes or ' single quotes:

# %%
print("This will work!")
print('This will also work!')

# %% [markdown]
# # Print Without a New Line
# By default, the print() function ends with a new line.
#
# If you want to print multiple words on the same line, you can use the end parameter:

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")

# %%
#Print Numbers
print(5)
print(3.14)
print(-7)
print(2 + 3)
print(10 - 4)
print(3 * 5)
print(8 / 2)
print(2 ** 3)  # Exponentiation
print(10 % 3)  # Modulus
print(15 // 4)  # Floor Division    
print(5 > 2)   # Greater than
print(3 < 1)   # Less than
print(4 == 4)  # Equal to
print(5 != 3)  # Not equal to
print(3 >= 2)  # Greater than or equal to
print(2 <= 5)  # Less than or equal to
print(True)
print(False)
print(5 > 2 and 3 < 4)  # Logical AND
print(5 > 2 or 3 > 4)   # Logical OR
print(not (5 > 2))      # Logical NOT
print(10 + 5 * 2)  # Operator precedence
print((10 + 5) * 2)  # Using parentheses to change precedence
print("Hello" + " " + "World!")  # String concatenation
print("Hello " * 3)  # String repetition
print(len("Hello"))  # Length of a string
print("Hello".upper())  # Convert to uppercase
print("WORLD".lower())  # Convert to lowercase
print("Hello World".replace("World", "Python"))  # Replace substring
print("Hello World".split())  # Split string into a list
print(10 // 3)  # Floor division
print(2 ** 4)  # Exponentiation
print(round(3.14159, 2))  # Rounding a float
print(abs(-7))  # Absolute value
print(divmod(10, 3))  # Quotient and remainder
print(bin(10))  # Binary representation
print(hex(255))  # Hexadecimal representation
print(oct(8))   # Octal representation
print(bool(1))  # Convert to boolean
print(bool(0))  # Convert to boolean
print(bool(""))  # Convert to boolean
print(bool("Hello"))  # Convert to boolean
