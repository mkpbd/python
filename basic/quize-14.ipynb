# %%
data ={
    "Name": ["alice", "Bob", "Charline"],
    "Age":[25, 30, 35],
    "City":["New York", "London New", "Paris"]
}

# %%
import pandas as pd
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age        City
# 0     alice   25    New York
# 1       Bob   30  London New
# 2  Charline   35       Paris

# %%
print(df.loc[df['City'].str.contains("New")])
# Out:
#     Name  Age        City
# 0  alice   25    New York
# 1    Bob   30  London New
